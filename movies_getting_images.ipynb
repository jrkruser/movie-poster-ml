# %% [markdown]
# ## Data Acquisition
# We have acquired a Kaggle dataset with data corresponding to about 700,000 movies. We would like to combine aspects of this data with data from the OMDb database to additionally acquire movie poster images for our neural network to process as well as other data fields corresponding to movie Rating (PG, R, etc) as well as ratings (IMDB, Metacritic).

# %%
import pandas as pd

# %%
# The data from the Kaggle page
df = pd.read_csv('movies.csv')

# %% [markdown]
# https://www.kaggle.com/datasets/akshaypawar7/millions-of-movies/data

# %%
df.head(1)
# Out:
#        id              title                         genres original_language  \
# 0  615656  Meg 2: The Trench  Action-Science Fiction-Horror                en
#
#                                             overview  popularity  \
# 0  An exploratory dive into the deepest depths of...    8763.998
#
#                                 production_companies release_date  \
# 0  Apelles Entertainment-Warner Bros. Pictures-di...   2023-08-02
#
#         budget      revenue  runtime    status            tagline  \
# 0  129000000.0  352056482.0    116.0  Released  Back for seconds.
#
#    vote_average  vote_count  \
# 0         7.079      1365.0
#
#                                              credits  \
# 0  Jason Statham-Wu Jing-Shuya Sophia Cai-Sergio ...
#
#                               keywords                       poster_path  \
# 0  based on novel or book-sequel-kaiju  /4m1Au3YkjqsxF8iwQy0fPYSxE0h.jpg
#
#                       backdrop_path  \
# 0  /qlxy8yo5bcgUw2KAmmojUKp4rHd.jpg
#
#                                      recommendations
# 0  1006462-298618-569094-1061181-346698-1076487-6...

# %% [markdown]
# #### Select relevant subset
# For the purpose of our project we will focus on movies with `revenue` > 100,000 USD and `original_language` of english.

# %%
# Filter the DataFrame for movies with revenue > 100,000
df_filtered = df[df['revenue'] > 100000][['title', 'release_date', 'original_language','genres','budget','revenue','runtime']].copy()
# Filter the DataFrame for movies with revenue > 100,000
df_filtered = df_filtered[df_filtered['original_language'] == 'en'].copy()

# Extract the year from the 'release_date' column
df_filtered['year'] = df_filtered['release_date'].str[:4]

# Check the filtered DataFrame
df_filtered.head(2)
# Out:
#                  title release_date original_language  \
# 0    Meg 2: The Trench   2023-08-02                en
# 1  The Pope's Exorcist   2023-04-05                en
#
#                           genres       budget      revenue  runtime  year
# 0  Action-Science Fiction-Horror  129000000.0  352056482.0    116.0  2023
# 1        Horror-Mystery-Thriller   18000000.0   65675816.0    103.0  2023

# %% [markdown]
# #### Create columns in our DF for OMDb data to load into

# %%
# Add empty columns for the OMDb data
df_filtered['Rated'] = None
df_filtered['Poster'] = None
df_filtered['Ratings'] = None
df_filtered['Metascore'] = None
df_filtered['imdbRating'] = None
df_filtered['imdbVotes'] = None
df_filtered['imdbID'] = None

# Check the DataFrame structure after adding new columns
df_filtered.head(2)
# Out:
#                  title release_date original_language  \
# 0    Meg 2: The Trench   2023-08-02                en
# 1  The Pope's Exorcist   2023-04-05                en
#
#                           genres       budget      revenue  runtime  year  \
# 0  Action-Science Fiction-Horror  129000000.0  352056482.0    116.0  2023
# 1        Horror-Mystery-Thriller   18000000.0   65675816.0    103.0  2023
#
#   Rated Poster Ratings Metascore imdbRating imdbVotes imdbID
# 0  None   None    None      None       None      None   None
# 1  None   None    None      None       None      None   None

# %%
# Remove films with troublesome characters
df_filtered = df_filtered[~df_filtered['title'].str.contains(r'[\\/]', regex=True)].copy()

# %% [markdown]
# #### The following function accesses the OMDb api and acquires the necessary data
# Where available, data while be stored in filtered_df. Movie posters will be stored in separate folder with the path to images stored in the `Poster` column of the dataframe. Upon completion of the function execution, updated data will be stored as 'omdb_enriched_data.csv'
#
# While not perfect, the following code was successfull in acquiring poster images for about 8600 films. A data cleaning step is needed to follow.

# %%
import requests
import os
import time
import pandas as pd

# Function to fetch OMDb data and download poster images, then save to CSV
def fetch_omdb_data_and_update_df(df_filtered, api_key, output_csv='omdb_enriched_data.csv', limit=2000, timeout_duration=10):
    count = 0
    # Ensure the poster directory exists
    if not os.path.exists('posters'):
        os.makedirs('posters')

    for index, row in df_filtered.iterrows():
        # Skip rows where OMDb data has already been fetched
        if pd.notna(row['imdbID']):
            print(f"Skipping {row['title']} ({row['year']}) - already processed.")
            continue

        title = row['title']
        year = row['year']

        # Ensure the year is a string and remove any decimals
        year = str(int(float(year))) if pd.notna(year) else ''

        print(f"Fetching data for: {title} ({year})")

        # API request with title and year
        url = f"http://www.omdbapi.com/?t={title}&y={year}&apikey={api_key}"
        response = requests.get(url)

        if response.status_code == 200:
            data = response.json()

            # Check if the movie was found
            if data.get('Response', 'False') == 'True':
                # Populate the DataFrame with OMDb data
                df_filtered.at[index, 'Rated'] = data.get('Rated')
                df_filtered.at[index, 'Ratings'] = data.get('Ratings')  # is a list of ratings
                df_filtered.at[index, 'Metascore'] = pd.to_numeric(data.get('Metascore'), errors='coerce')
                df_filtered.at[index, 'imdbRating'] = pd.to_numeric(data.get('imdbRating'), errors='coerce')
                df_filtered.at[index, 'imdbVotes'] = data.get('imdbVotes')
                df_filtered.at[index, 'imdbID'] = data.get('imdbID')

                # Download the poster if available
                poster_url = data.get('Poster')
                if poster_url and poster_url != "N/A":
                    try:
                        img_data = requests.get(poster_url, timeout=timeout_duration).content
                        file_name = f"posters/{title.replace(' ', '_')}_{year}_photo.jpg"
                        with open(file_name, "wb") as img_file:
                            img_file.write(img_data)

                        # Store the poster path in the DataFrame
                        df_filtered.at[index, 'Poster'] = file_name
                        print(f"Poster downloaded and saved as {file_name}")
                    except requests.exceptions.Timeout:
                        print(f"Timeout occurred for {title} ({year}). Skipping poster.")
                else:
                    print(f"No poster available for {title} ({year})")

            else:
                print(f"Movie not found in OMDb for {title} ({year})")

        else:
            print(f"Failed to fetch data for {title} ({year}). Status code: {response.status_code}")

        # Sleep for 1 second to avoid overwhelming the API
        time.sleep(1)

        count += 1
        print(f"Progress: {count}/{limit} movies processed.")
        if count >= limit:
            break

    # Save the updated DataFrame to a CSV file
    df_filtered.to_csv(output_csv, index=False)
    print(f"Data saved to {output_csv}")

    return df_filtered

# %%
# Load previously saved data if exists
try:
    df_filtered = pd.read_csv('omdb_enriched_data.csv')  
    print("Loaded existing OMDb enriched data.")
except FileNotFoundError:
    print("No previous data found. Starting fresh with df_filtered.")

api_key = "**********"
# Run function, set limit as desired
df_filtered = fetch_omdb_data_and_update_df(df_filtered, api_key, limit=800)

# Check the updated DataFrame
df_filtered.head(2)
# Out:
# Loaded existing OMDb enriched data.
# Skipping Meg 2: The Trench (2023.0) - already processed.
# Skipping The Pope's Exorcist (2023.0) - already processed.
# Skipping Deadpool & Wolverine (2024.0) - already processed.
# Skipping Transformers: Rise of the Beasts (2023.0) - already processed.
# Skipping Dune: Part Two (2024.0) - already processed.
# Skipping Ant-Man and the Wasp: Quantumania (2023.0) - already processed.
# Skipping Creed III (2023.0) - already processed.
# Skipping Insidious: The Red Door (2023.0) - already processed.
# Skipping Despicable Me 4 (2024.0) - already processed.
# Skipping Spider-Man: Across the Spider-Verse (2023.0) - already processed.
# Skipping Kingdom of the Planet of the Apes (2024.0) - already processed.
# Skipping Beetlejuice Beetlejuice (2024.0) - already processed.
# Skipping Aquaman and the Lost Kingdom (2023.0) - already processed.
# Skipping Shazam! Fury of the Gods (2023.0) - already processed.
# Skipping Knights of the Zodiac (2023.0) - already processed.
# Skipping Furiosa: A Mad Max Saga (2024.0) - already processed.
# Skipping Napoleon (2023.0) - already processed.
# Skipping Bad Boys: Ride or Die (2024.0) - already processed.
# Skipping The Nun II (2023.0) - already processed.
# Skipping The Creator (2023.0) - already processed.
# Skipping Alien: Romulus (2024.0) - already processed.
# Skipping The Hunger Games: The Ballad of Songbirds & Snakes (2023.0) - already processed.
# Skipping IF (2024.0) - already processed.
# Skipping A Quiet Place: Day One (2024.0) - already processed.
# Skipping Shotgun Wedding (2022.0) - already processed.
# Skipping Retribution (2023.0) - already processed.
# Skipping Puss in Boots: The Last Wish (2022.0) - already processed.
# Skipping The Garfield Movie (2024.0) - already processed.
# Skipping Migration (2023.0) - already processed.
# Skipping Guy Ritchie's The Covenant (2023.0) - already processed.
# Fetching data for: Expend4bles (2023)
# Failed to fetch data for Expend4bles (2023). Status code: 401
# Progress: 1/800 movies processed.
# Skipping Teenage Mutant Ninja Turtles: Mutant Mayhem (2023.0) - already processed.
# Skipping John Wick: Chapter 4 (2023.0) - already processed.
# Skipping Evil Dead Rise (2023.0) - already processed.
# Skipping The Exorcism (2024.0) - already processed.
# Skipping Fast X (2023.0) - already processed.
# Skipping Prey for the Devil (2022.0) - already processed.
# Skipping Twisters (2024.0) - already processed.
# Skipping The Fall Guy (2024.0) - already processed.
# Skipping I Saw the TV Glow (2024.0) - already processed.
# Skipping The Exorcist: Believer (2023.0) - already processed.
# Skipping Ghostbusters: Frozen Empire (2024.0) - already processed.
# Skipping Guardians of the Galaxy Vol. 2 (2017.0) - already processed.
# Skipping Mission: Impossible - Dead Reckoning Part One (2023.0) - already processed.
# Skipping Killers of the Flower Moon (2023.0) - already processed.
# Skipping Star Wars (1977.0) - already processed.
# Skipping 65 (2023.0) - already processed.
# Skipping Glass Onion: A Knives Out Mystery (2022.0) - already processed.
# Skipping Oppenheimer (2023.0) - already processed.
# Skipping Inside Out (2015.0) - already processed.
# Skipping A Haunting in Venice (2023.0) - already processed.
# Skipping Violent Night (2022.0) - already processed.
# Skipping No Hard Feelings (2023.0) - already processed.
# Skipping Thor: Love and Thunder (2022.0) - already processed.
# Skipping Medieval (2022.0) - already processed.
# Skipping The Chronicles of Narnia: The Lion, the Witch and the Wardrobe (2005.0) - already processed.
# Skipping Saw X (2023.0) - already processed.
# Skipping Tarot (2024.0) - already processed.
# Skipping Godzilla x Kong: The New Empire (2024.0) - already processed.
# Skipping Con Air (1997.0) - already processed.
# Skipping Terrifier 2 (2022.0) - already processed.
# Skipping Poor Things (2023.0) - already processed.
# Skipping Creed II (2018.0) - already processed.
# Skipping Jurassic World Dominion (2022.0) - already processed.
# Skipping Creed (2015.0) - already processed.
# Skipping Strange World (2022.0) - already processed.
# Skipping Beast (2022.0) - already processed.
# Skipping Horizon: An American Saga - Chapter 1 (2024.0) - already processed.
# Skipping Missing (2023.0) - already processed.
# Skipping Bullet Train (2022.0) - already processed.
# Skipping The First Omen (2024.0) - already processed.
# Skipping Avatar: The Way of Water (2022.0) - already processed.
# Skipping Sonic the Hedgehog 2 (2022.0) - already processed.
# Skipping Top Gun: Maverick (2022.0) - already processed.
# Skipping Avatar (2009.0) - already processed.
# Skipping Freelance (2023.0) - already processed.
# Skipping Godzilla: King of the Monsters (2019.0) - already processed.
# Skipping Encanto (2021.0) - already processed.
# Skipping The Flash (2023.0) - already processed.
# Skipping The Crow (2024.0) - already processed.
# Skipping Blue Beetle (2023.0) - already processed.
# Skipping Hacksaw Ridge (2016.0) - already processed.
# Skipping Hypnotic (2023.0) - already processed.
# Skipping Five Nights at Freddy's (2023.0) - already processed.
# Skipping Black Adam (2022.0) - already processed.
# Skipping The Beekeeper (2024.0) - already processed.
# Skipping M3GAN (2022.0) - already processed.
# Skipping The Super Mario Bros. Movie (2023.0) - already processed.
# Skipping Venom: Let There Be Carnage (2021.0) - already processed.
# Skipping Godzilla (2014.0) - already processed.
# Skipping Wonka (2023.0) - already processed.
# Skipping Eight Legged Freaks (2002.0) - already processed.
# Skipping Deadpool 2 (2018.0) - already processed.
# Skipping Jeepers Creepers: Reborn (2022.0) - already processed.
# Skipping Mad Max: Fury Road (2015.0) - already processed.
# Skipping Guardians of the Galaxy (2014.0) - already processed.
# Fetching data for: Late Night with the Devil (2024)
# Failed to fetch data for Late Night with the Devil (2024). Status code: 401
# Progress: 2/800 movies processed.
# Skipping Deadpool (2016.0) - already processed.
# Skipping Harry Potter and the Goblet of Fire (2005.0) - already processed.
# Skipping Evil Dead II (1987.0) - already processed.
# Skipping Bad Boys (1995.0) - already processed.
# Skipping Spider-Man: No Way Home (2021.0) - already processed.
# Fetching data for: Harry Potter and the Philosopher's Stone (2001)
# Failed to fetch data for Harry Potter and the Philosopher's Stone (2001). Status code: 401
# Progress: 3/800 movies processed.
# Skipping A Street Cat Named Bob (2016.0) - already processed.
# Skipping Alice, Darling (2022.0) - already processed.
# Skipping Shrek (2001.0) - already processed.
# Skipping Guardians of the Galaxy Vol. 3 (2023.0) - already processed.
# Skipping Doctor Strange (2016.0) - already processed.
# Skipping Avengers: Endgame (2019.0) - already processed.
# Skipping Transformers: Age of Extinction (2014.0) - already processed.
# Skipping The Lord of the Rings: The Fellowship of the Ring (2001.0) - already processed.
# Skipping Kama Sutra: A Tale of Love (1996.0) - already processed.
# Skipping Harry Potter and the Order of the Phoenix (2007.0) - already processed.
# Skipping Bad Boys II (2003.0) - already processed.
# Skipping Beverly Hills Cop (1984.0) - already processed.
# Skipping Madame Web (2024.0) - already processed.
# Skipping Fantastic Beasts: The Secrets of Dumbledore (2022.0) - already processed.
# Skipping Kung Fu Panda (2008.0) - already processed.
# Skipping Avengers: Infinity War (2018.0) - already processed.
# Skipping Fifty Shades Freed (2018.0) - already processed.
# Skipping Meet the Robinsons (2007.0) - already processed.
# Skipping Charlie and the Chocolate Factory (2005.0) - already processed.
# Skipping Blade Runner 2049 (2017.0) - already processed.
# Skipping Interstellar (2014.0) - already processed.
# Skipping Garfield (2004.0) - already processed.
# Skipping After Ever Happy (2022.0) - already processed.
# Skipping Sound of Freedom (2023.0) - already processed.
# Skipping Harry Potter and the Prisoner of Azkaban (2004.0) - already processed.
# Skipping PAW Patrol: The Mighty Movie (2023.0) - already processed.
# Skipping After Everything (2023.0) - already processed.
# Skipping Hotel Transylvania: Transformania (2022.0) - already processed.
# Skipping Till (2022.0) - already processed.
# Skipping Orphan: First Kill (2022.0) - already processed.
# Skipping Fly Me to the Moon (2024.0) - already processed.
# Skipping Knock at the Cabin (2023.0) - already processed.
# Skipping Coraline (2009.0) - already processed.
# Skipping Cocaine Bear (2023.0) - already processed.
# Skipping Dawn of the Planet of the Apes (2014.0) - already processed.
# Skipping Fifty Shades of Grey (2015.0) - already processed.
# Skipping The Autopsy of Jane Doe (2016.0) - already processed.
# Skipping The Whale (2022.0) - already processed.
# Skipping Titanic (1997.0) - already processed.
# Skipping Turning Red (2022.0) - already processed.
# Fetching data for: Last Looks (2022)
# Failed to fetch data for Last Looks (2022). Status code: 401
# Progress: 4/800 movies processed.
# Skipping Kong: Skull Island (2017.0) - already processed.
# Skipping The Batman (2022.0) - already processed.
# Skipping Saw II (2005.0) - already processed.
# Skipping Get Out (2017.0) - already processed.
# Skipping Morbius (2022.0) - already processed.
# Skipping The Lost City (2022.0) - already processed.
# Skipping Beverly Hills Cop II (1987.0) - already processed.
# Skipping The Hunger Games: Mockingjay - Part 1 (2014.0) - already processed.
# Skipping North by Northwest (1959.0) - already processed.
# Skipping Monkey Man (2024.0) - already processed.
# Skipping Harry Potter and the Chamber of Secrets (2002.0) - already processed.
# Fetching data for: Potworny (2022)
# Failed to fetch data for Potworny (2022). Status code: 401
# Progress: 5/800 movies processed.
# Skipping The Help (2011.0) - already processed.
# Skipping Operation Fortune: Ruse de Guerre (2023.0) - already processed.
# Skipping Barbie (2023.0) - already processed.
# Skipping The Nun (2018.0) - already processed.
# Skipping Twister (1996.0) - already processed.
# Skipping Shrek 2 (2004.0) - already processed.
# Skipping Shang-Chi and the Legend of the Ten Rings (2021.0) - already processed.
# Skipping The Hunger Games: Catching Fire (2013.0) - already processed.
# Skipping Dune (2021.0) - already processed.
# Skipping Big Hero 6 (2014.0) - already processed.
# Skipping Memory (2022.0) - already processed.
# Skipping Uncharted (2022.0) - already processed.
# Skipping The Conjuring: The Devil Made Me Do It (2021.0) - already processed.
# Skipping Black Panther: Wakanda Forever (2022.0) - already processed.
# Skipping Joker (2019.0) - already processed.
# Skipping A Good Day to Die Hard (2013.0) - already processed.
# Skipping Coco (2017.0) - already processed.
# Skipping Back to the Future (1985.0) - already processed.
# Skipping Beverly Hills Cop III (1994.0) - already processed.
# Skipping The Northman (2022.0) - already processed.
# Skipping The Menu (2022.0) - already processed.
# Skipping Avengers: Age of Ultron (2015.0) - already processed.
# Skipping Past Lives (2023.0) - already processed.
# Skipping Spider-Man: Into the Spider-Verse (2018.0) - already processed.
# Skipping Empire of Light (2022.0) - already processed.
# Skipping Brothers (2009.0) - already processed.
# Skipping After (2019.0) - already processed.
# Skipping A Haunted House (2013.0) - already processed.
# Skipping Harry Potter and the Half-Blood Prince (2009.0) - already processed.
# Skipping Harry Potter and the Deathly Hallows: Part 2 (2011.0) - already processed.
# Skipping The Emperor's New Groove (2000.0) - already processed.
# Skipping Tenet (2020.0) - already processed.
# Skipping The Lord of the Rings: The Two Towers (2002.0) - already processed.
# Skipping Dog (2022.0) - already processed.
# Skipping Gone Girl (2014.0) - already processed.
# Skipping Triangle of Sadness (2022.0) - already processed.
# Skipping Monsters, Inc. (2001.0) - already processed.
# Fetching data for: Daddio (2024)
# Failed to fetch data for Daddio (2024). Status code: 401
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 10
#       8 api_key = "**********"
#       9 # Run function, set limit as desired
# ---> 10 df_filtered = fetch_omdb_data_and_update_df(df_filtered, api_key, limit=800)
#      12 # Check the updated DataFrame
#      13 df_filtered.head(2)
#
# Cell In[7], line 68, in fetch_omdb_data_and_update_df(df_filtered, api_key, output_csv, limit, timeout_duration)
#      65     print(f"Failed to fetch data for {title} ({year}). Status code: {response.status_code}")
#      67 # Sleep for 1 second to avoid overwhelming the API
# ---> 68 time.sleep(1)
#      70 count += 1
#      71 print(f"Progress: {count}/{limit} movies processed.")
#
# KeyboardInterrupt:
